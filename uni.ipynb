# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
multi=pd.read_csv('Book2.csv')

# %%
multi.head()
# Out:
#    temp(in celcius)  ice cream sales
# 0                20             2000
# 1                25             2500
# 2                35             5000
# 3                43             7800

# %%
multi['temp(in celcius)'].mean()
# Out:
# 30.75

# %%
multi['ice cream sales'].mean()
# Out:
# 4325.0

# %%
multi['temp(in celcius)'].median()
# Out:
# 30.0

# %%
multi['ice cream sales'].median()
# Out:
# 3750.0

# %%
plt.bar(multi['temp(in celcius)'],multi['ice cream sales'],color ='maroon', 
        width = 0.4)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.hist(multi['ice cream sales'])
# Out:
# (array([2., 0., 0., 0., 0., 1., 0., 0., 0., 1.]),
#  array([2000., 2580., 3160., 3740., 4320., 4900., 5480., 6060., 6640.,
#         7220., 7800.]),
#  <BarContainer object of 10 artists>)

# %%
np.var(multi['temp(in celcius)'])
# Out:
# 79.1875

# %%
plt.scatter(multi['temp(in celcius)'],multi['ice cream sales'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
