# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('eda.csv')

# %%
df.head()
# Out:
#    household ID  Household Size  Annual income  no of pets
# 0             1               2             37           0
# 1             2               4             49           0
# 2             3               4             58           1
# 3             4               1             68           3
# 4             5               3             61           2

# %%
df.tail()
# Out:
#    household ID  Household Size  Annual income  no of pets
# 5             6               5             64           2
# 6             7               6             79           1
# 7             8               4             89           1
# 8             9               7            104           1
# 9            10               2             95           0

# %%
df.describe()
# Out:
#        household ID  Household Size  Annual income  no of pets
# count      10.00000       10.000000      10.000000   10.000000
# mean        5.50000        3.800000      70.400000    1.100000
# std         3.02765        1.873796      21.125025    0.994429
# min         1.00000        1.000000      37.000000    0.000000
# 25%         3.25000        2.250000      58.750000    0.250000
# 50%         5.50000        4.000000      66.000000    1.000000
# 75%         7.75000        4.750000      86.500000    1.750000
# max        10.00000        7.000000     104.000000    3.000000

# %%
newdf=df.drop("household ID",axis='columns')

# %%
newdf.head()
# Out:
#    Household Size  Annual income  no of pets
# 0               2             37           0
# 1               4             49           0
# 2               4             58           1
# 3               1             68           3
# 4               3             61           2

# %%
newdf.nunique()
# Out:
# Household Size     7
# Annual income     10
# no of pets         4
# dtype: int64

# %%
newdf.isnull().sum()
# Out:
# Household Size    0
# Annual income     0
# no of pets        0
# dtype: int64

# %%
plt.bar(newdf['Household Size'],newdf['no of pets'])
plt.xlabel('Household size')
plt.ylabel('no of pets')
plt.show()

# %%
plt.bar(newdf['Annual income'],newdf['no of pets'])
plt.xlabel('Annual income')
plt.ylabel('no of pets')
plt.show()

# %%
sns.pairplot(newdf)
# Out:
# C:\Users\karti\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(x='Household Size', y='no of pets', data=newdf)
# Out:
# <Axes: xlabel='Household Size', ylabel='no of pets'>

# %%
sns.heatmap(newdf.corr(),annot=True, fmt='.2f', cmap='Pastel2', linewidths=2)
# Out:
# <Axes: >
