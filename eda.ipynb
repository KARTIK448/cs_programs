# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('response.csv')

# %%
data.head()
# Out:
#              name  ill  workout  fastfood  stress  Unnamed: 5
# 0          Jayesh    1        1         7       7         NaN
# 1   Rutvik Mahale    1        1        20       4         NaN
# 2   Mayur Bhavsar    1        5         9       8         NaN
# 3     Aryan Patil    0        4        13       1         NaN
# 4  Anushka Patil     1        2         5       7         NaN

# %%
data.tail()
# Out:
#                 name  ill  workout  fastfood  stress  Unnamed: 5
# 30       Sagar abrol    2        1         9       7         NaN
# 31  Sharvayu Dhemse     1        1         7       9         NaN
# 32            Prawar    3        0        31       5         NaN
# 33       Yash patil     1        0        25       6         NaN
# 34     Shreya Patil     1        0         4       7         NaN

# %%
data.shape
# Out:
# (35, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        35 non-null     object
#  1   ill         35 non-null     int64
#  2   workout     35 non-null     int64
#  3   fastfood    35 non-null     int64
#  4   stress      35 non-null     int64
#  5   Unnamed: 5  0 non-null      float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 1.8+ KB

# %%
data.describe()
# Out:
#              ill    workout   fastfood     stress  Unnamed: 5
# count  35.000000  35.000000  35.000000  35.000000         0.0
# mean    1.428571   1.514286  12.228571   6.714286         NaN
# std     1.312513   1.462702  10.569339   2.177038         NaN
# min     0.000000   0.000000   0.000000   1.000000         NaN
# 25%     1.000000   1.000000   4.000000   6.000000         NaN
# 50%     1.000000   1.000000   8.000000   7.000000         NaN
# 75%     2.000000   2.000000  20.000000   8.000000         NaN
# max     5.000000   5.000000  31.000000  10.000000         NaN

# %%
data.isnull().sum()
# Out:
# name           0
# ill            0
# workout        0
# fastfood       0
# stress         0
# Unnamed: 5    35
# dtype: int64

# %%
sns.pairplot(data.drop(['name',],axis=1),hue='ill',height=2)
# Out:
# C:\Users\karti\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
student=data.drop(['name'],axis=1)

# %%
correlation=student.corr()

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns)
# Out:
# <Axes: >

# %%
sns.pairplot(data)
# Out:
# C:\Users\karti\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
